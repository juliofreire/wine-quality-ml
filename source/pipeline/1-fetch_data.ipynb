# %% [markdown]
# # Universidade Federal do Rio Grande do Norte

# %% [markdown]
# ## Programa de Pós-Graduação em Engenharia Elétrica e de Computação
# ## EEC1509 - Aprendizagem de Máquina

# %% [markdown]
# # Group

# %% [markdown]
# ## João Lucas Correia Barbosa de Farias

# %% [markdown]
# ## Júlio Freire Peixoto Gomes

# %% [markdown]
# # Project 1 - Red Wine Quality Classification

# %% [markdown]
# ## About the Project
# This project is divided in 8 files including this one, where each one represents one step in the process of deploying a machine learning algorithm. In this case, we choose a Decision Tree algorithm as Classifier due to its simplicity and because it is the algorithm we saw in class. However, other classifiers may perform a better fit.
#
# The dataset has some characteristics about red wines and their quality based on that information, so our mission is to predict the quality of any red wine using the same information we used to train our model.

# %% [markdown]
# ### The details about the dataset are shown below.
#
# For more information, read [Cortez et al., 2009].
#
# ### Input variables (based on physicochemical tests):
#
#
# 1. fixed acidity
#
# 2. volatile acidity
#
# 3. citric acid
#
# 4. residual sugar
#
# 5. chlorides
#
# 6. free sulfur dioxide
#
# 7. total sulfur dioxide
#
# 8. density
#
# 9. pH
#
# 10. sulphates
#
# 11. alcohol
#
# Output variable (based on sensory data):
#
# 12. quality (score between 0 and 10)

# %% [markdown]
# ## The dataset was taken from Kaggle:
# https://www.kaggle.com/datasets/uciml/red-wine-quality-cortez-et-al-2009

# %% [markdown]
# # 1.0 Install and Load Libraries

# %%
# !pip install wandb

# %%
import wandb
import pandas as pd

# %% [markdown]
# # 2.0 Fetch Data

# %% [markdown]
# In this first step, the raw data from the dataset is uploaded to wandb. This way, in the following steps, we are able to communicate with wandb and retrieve the dataset.

# %%
# importing database from google drive
input = pd.read_csv("winequality-red.csv")

# analyzing first lines of dataset
input.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# 3      9.8        6
# 4      9.4        5

# %%
# creating raw_data.csv file to upload to wandb
input.to_csv("raw_data.csv", index=False)

# %%
# login to wandb account
# !wandb login --relogin
# Out:
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit:
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc

# %%
# upload file raw_data.csv (dataset) to wandb under the
# project called wine_price
# !wandb artifact put \
      --name ppgeec-ml-jj/red_wine_quality/raw_data.csv \
      --type raw_data \
      --description "Raw data from Red Wine Quality Dataset" raw_data.csv
# Out:
# wandb: Uploading file raw_data.csv to: "ppgeec-ml-jj/red_wine_quality/raw_data.csv:latest" (raw_data)
# wandb: Currently logged in as: jotafarias (ppgeec-ml-jj). Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.12.17
# wandb: Run data is saved locally in /content/wandb/run-20220526_194402-1nvwc2qd
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run dashing-bee-1
# wandb: ⭐️ View project at https://wandb.ai/ppgeec-ml-jj/red_wine_quality
# wandb: 🚀 View run at https://wandb.ai/ppgeec-ml-jj/red_wine_quality/runs/1nvwc2qd
# Artifact uploaded, use this artifact in a run by adding:
#
#     artifact = run.use_artifact("ppgeec-ml-jj/red_wine_quality/raw_data.csv:latest")
#
# wandb: Waiting for W&B process to finish... (success).
# wandb:
# wandb: Synced dashing-bee-1: https://wandb.ai/ppgeec-ml-jj/red_wine_quality/runs/1nvwc2qd
# wandb: Synced 5 W&B file(s), 0 media file(s), 1 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20220526_194402-1nvwc2qd/logs
